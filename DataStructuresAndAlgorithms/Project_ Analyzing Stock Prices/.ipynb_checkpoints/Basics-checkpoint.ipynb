# %% [markdown]
# # Analyzing Stock Prices
#
# In this project, I work with stock market data that was downloaded from Yahoo Finance using the yahoo_finance Python package. This data consists of the daily stock prices from 2007-1-1 to 2017-04-17 for several hundred stock symbols traded on the NASDAQ stock exchange, stored in the prices folder. The download_data.py script in the same folder as the Jupyter notebook was used to download all of the stock price data. Each file in the prices folder is named for a specific stock symbol, and contains the:
#
# - date -- date that the data is from.
# - close -- the closing price on that day, which is the price when the trading day ends.
# - open -- the opening price on that day, which is the price when the trading day starts.
# - high -- the highest price the stock reached during trading.
#  -low -- the lowest price the stock reached during trading.
# - volume -- the number of shares that were traded during the day.

# %% [markdown]
# ## Data Structure for each layer to represent data
#
# - Layer 1 : Use stock symbol as key,
# - Layer 2 & 3: datafame that contains stock price over time period with columns data as value
#
# Use dict data structure, which would make search by stock symbol easier.  A dataframe would allow efficient use of panda and numpy libries for data analysis.

# %%
import concurrent.futures
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# The concurrent.futures module provides a high-level 
# interface for asynchronously executing callables.

# %% [markdown]
# ### Read data from csv

# %%
directory = 'prices'
filenames = os.listdir('prices')
#print(filenames)
data = {}

# %%
with concurrent.futures.ProcessPoolExecutor() as executor:
    for file in filenames:
        key = file[:-4]
        data[key] = pd.read_csv(os.path.join(directory, file))

# %%
#print(data['aapl'])
data['aapl'].head()
# Out:
#          date      close       open       high        low     volume
# 0  2007-01-03  83.800002  86.289999  86.579999  81.899999  309579900
# 1  2007-01-04  85.659998  84.050001  85.949998  83.820003  211815100
# 2  2007-01-05  85.049997  85.770000  86.199997  84.400002  208685400
# 3  2007-01-08  85.470000  85.959998  86.529998  85.280003  199276700
# 4  2007-01-09  92.570003  86.450003  92.979999  85.150000  837324600

# %% [markdown]
# ## Explotory Data Analysis

# %% [markdown]
# #### The average closing price of all stocks over the time period.

# %%
time_periods = data['aapl']['date']
stock_symbols = data.keys()

# %%
avg_closing_price_all = pd.DataFrame()
avg_closing_price_all['date'] = time_periods
for key in data:
    avg_closing_price_all[key] = data[key]['close']
avg_closing_price_all.head(3)
# Out:
#          date       fmbi      cmcsa   boom   ctg   cpah       abco   acta  \
# 0  2007-01-03  38.930000  42.660001  26.90  4.75  0.435  53.959999  10.32
# 1  2007-01-04  38.880001  43.050001  27.76  4.75  0.430  54.500000  10.33
# 2  2007-01-05  37.869999  42.550000  26.77  4.75  0.380  53.709999  10.15
#
#     ecpg  asrv    ...       algn       aray  esxb       cvgi       ceco  \
# 0  12.27  4.85    ...      13.35  28.469999  7.15  22.100000  25.030001
# 1  12.43  4.78    ...      13.60  29.250000  7.10  21.780001  25.040001
# 2  12.04  4.82    ...      13.64  28.549999  7.15  20.530001  25.309999
#
#     cybe   fisi       agys      arcw       aciw
# 0  12.85  23.09  20.450001  0.100035  32.920000
# 1  12.90  22.73  19.490000  0.100035  33.700001
# 2  13.00  22.84  18.730000  0.100035  33.850001
#
# [3 rows x 561 columns]

# %% [markdown]
# #### The average volumn for each stock

# %% [markdown]
# #### The difference between the average opening price and the average closing price for each stock.

# %% [markdown]
# #### The difference between the average high and the average low for each stock.

# %% [markdown]
# ## Most Traded Stock Each Day

# %%
stocks_volumes = pd.DataFrame()
stocks_volumes['date'] = time_periods
for key in data:
    stocks_volumes[key] = data[key]['volume']
stocks_volumes.head(3)
# Out:
#          date    fmbi     cmcsa    boom    ctg   cpah    abco    acta   ecpg  \
# 0  2007-01-03  275000  39543600  486000  42100  200.0  523000  351100  52600
# 1  2007-01-04  208700  38122400  888000  67200  300.0  225800  303200  53400
# 2  2007-01-05  321300  25701200  462100  31900  300.0  242800  518100  80200
#
#     asrv   ...        algn        aray  esxb    cvgi     ceco    cybe   fisi  \
# 0   6800   ...     1201200  19190700.0     0  149600  2377600   35600  26500
# 1  27800   ...      504600   3288700.0   800  114700   830500  122300  11000
# 2  31200   ...      435800    981100.0   800  182300  1099100   64600   5900
#
#      agys  arcw     aciw
# 0  993300   500  1339800
# 1  531000     0   981000
# 2  317700  3500  1509900
#
# [3 rows x 561 columns]

# %%
stocks_volumes['buse'].head()
# Out:
# 0    10500
# 1    11700
# 2    10900
# 3     6600
# 4     8300
# Name: buse, dtype: int64

# %%
columns = stocks_volumes.columns
columns
# Out:
# Index(['date', 'fmbi', 'cmcsa', 'boom', 'ctg', 'cpah', 'abco', 'acta', 'ecpg',
#        'asrv',
#        ...
#        'algn', 'aray', 'esxb', 'cvgi', 'ceco', 'cybe', 'fisi', 'agys', 'arcw',
#        'aciw'],
#       dtype='object', length=561)

# %%
columns = columns[1:]
def get_max_vol_stock(row):
    date = row[0]
    row = np.array(row)[1:]
    idx = np.argmax(row)
    return [date, columns[idx]]

# %%
most_traded_stock_by_day = stocks_volumes.apply(get_max_vol_stock, axis=1)  
most_traded_stock_by_day[:30]
# Out:
# 0     [2007-01-03, aapl]
# 1     [2007-01-04, aapl]
# 2     [2007-01-05, aapl]
# 3     [2007-01-08, aapl]
# 4     [2007-01-09, aapl]
# 5     [2007-01-10, aapl]
# 6     [2007-01-11, aapl]
# 7     [2007-01-12, aapl]
# 8     [2007-01-16, aapl]
# 9     [2007-01-17, aapl]
# 10    [2007-01-18, aapl]
# 11    [2007-01-19, aapl]
# 12    [2007-01-22, aapl]
# 13    [2007-01-23, aapl]
# 14    [2007-01-24, aapl]
# 15    [2007-01-25, aapl]
# 16    [2007-01-26, aapl]
# 17    [2007-01-29, aapl]
# 18    [2007-01-30, aapl]
# 19    [2007-01-31, aapl]
# 20    [2007-02-01, aapl]
# 21    [2007-02-02, aapl]
# 22    [2007-02-05, aapl]
# 23    [2007-02-06, aapl]
# 24    [2007-02-07, aapl]
# 25    [2007-02-08, aapl]
# 26    [2007-02-09, aapl]
# 27    [2007-02-12, aapl]
# 28    [2007-02-13, aapl]
# 29    [2007-02-14, aapl]
# dtype: object

# %% [markdown]
# ## High Transaction Day

# %%
# Compute total volume of trading for each day
def agg_volume(row):
    return row[1:].sum()
total_volume_by_day = pd.DataFrame()
total_volume_by_day['date'] = stocks_volumes['date']
total_volume_by_day['total_volume'] = stocks_volumes.apply(agg_volume, axis=1)     
total_volume_by_day.head()
# Out:
#          date  total_volume
# 0  2007-01-03  1.036523e+09
# 1  2007-01-04  8.375896e+08
# 2  2007-01-05  7.452139e+08
# 3  2007-01-08  7.468873e+08
# 4  2007-01-09  1.419223e+09

# %%
# Sort and find the 1- highest volume days overall
highest_10_volume_day_overall = total_volume_by_day.sort_values(by='total_volume', ascending=False).head(10)    
highest_10_volume_day_overall
# Out:
#            date  total_volume
# 265  2008-01-23  1.963754e+09
# 447  2008-10-10  1.769361e+09
# 141  2007-07-26  1.610858e+09
# 445  2008-10-08  1.598255e+09
# 264  2008-01-22  1.578117e+09
# 276  2008-02-07  1.557507e+09
# 438  2008-09-29  1.554716e+09
# 215  2007-11-08  1.552455e+09
# 261  2008-01-16  1.535759e+09
# 266  2008-01-24  1.533396e+09

# %%
highest_volume_dates = highest_10_volume_day_overall['date']
highest_volume_dates
# Out:
# 265    2008-01-23
# 447    2008-10-10
# 141    2007-07-26
# 445    2008-10-08
# 264    2008-01-22
# 276    2008-02-07
# 438    2008-09-29
# 215    2007-11-08
# 261    2008-01-16
# 266    2008-01-24
# Name: date, dtype: object

# %%
# all stock prices by date
stocks_prices = pd.DataFrame()
stocks_prices['date'] = time_periods
for key in data:
    stocks_prices[key] = data[key]['close']
stocks_prices.head()
# Out:
#          date       fmbi      cmcsa   boom   ctg   cpah       abco   acta  \
# 0  2007-01-03  38.930000  42.660001  26.90  4.75  0.435  53.959999  10.32
# 1  2007-01-04  38.880001  43.050001  27.76  4.75  0.430  54.500000  10.33
# 2  2007-01-05  37.869999  42.550000  26.77  4.75  0.380  53.709999  10.15
# 3  2007-01-08  38.169998  42.470000  26.49  4.75  0.400  53.639999  10.15
# 4  2007-01-09  38.119999  42.740001  25.84  4.75  0.375  54.060001  10.21
#
#     ecpg  asrv    ...       algn       aray  esxb       cvgi       ceco  \
# 0  12.27  4.85    ...      13.35  28.469999  7.15  22.100000  25.030001
# 1  12.43  4.78    ...      13.60  29.250000  7.10  21.780001  25.040001
# 2  12.04  4.82    ...      13.64  28.549999  7.15  20.530001  25.309999
# 3  11.92  4.76    ...      13.68  27.610001  7.15  20.209999  25.110001
# 4  11.63  4.82    ...      13.70  26.620001  7.15  21.049999  25.190001
#
#     cybe   fisi       agys      arcw       aciw
# 0  12.85  23.09  20.450001  0.100035  32.920000
# 1  12.90  22.73  19.490000  0.100035  33.700001
# 2  13.00  22.84  18.730000  0.100035  33.850001
# 3  13.20  22.90  18.830000  0.100035  34.130001
# 4  13.20  23.00  19.020000  0.100035  34.420000
#
# [5 rows x 561 columns]

# %%
highest_volume_day_prices_all = stocks_prices[stocks_prices['date'].isin(highest_volume_dates)]  

highest_volume_day_prices_all
# Out:
#            date       fmbi      cmcsa       boom   ctg    cpah       abco  \
# 141  2007-07-26  32.770000  27.209999  39.209999  4.30  0.3850  52.700001
# 215  2007-11-08  31.400000  19.820000  54.910000  4.98  0.4800  64.070000
# 261  2008-01-16  26.700001  18.180000  47.799999  4.58  0.4500  64.300003
# 264  2008-01-22  26.020000  16.650000  44.189999  4.08  0.4000  61.770000
# 265  2008-01-23  28.010000  17.260000  50.439999  4.25  0.4000  62.599998
# 266  2008-01-24  29.320000  17.440001  50.150002  4.40  0.3867  61.619999
# 276  2008-02-07  29.870001  17.379999  54.139999  4.03  0.4000  54.000000
# 438  2008-09-29  24.820000  18.010000  22.320000  5.50  1.1700  30.290001
# 445  2008-10-08  21.639999  16.990000  18.020000  5.60  0.8400  29.110001
# 447  2008-10-10  23.610001  15.360000  17.059999  5.85  1.0100  27.559999
#
#       acta   ecpg  asrv    ...           algn   aray  esxb   cvgi       ceco  \
# 141  12.06  11.25  3.70    ...      27.620001  13.73  7.43  15.30  31.230000
# 215  11.82  10.44  2.96    ...      17.040001  14.57  7.40  12.85  33.330002
# 261  10.10   7.85  2.75    ...      14.220000  10.50  7.40   9.67  20.670000
# 264   9.36   6.92  2.54    ...      12.980000  10.97  7.41   9.82  16.889999
# 265   9.71   7.40  2.53    ...      13.480000  10.69  7.46  10.29  17.430000
# 266   9.53   7.25  2.93    ...      13.120000  10.36  7.43   9.97  19.160000
# 276   9.07   7.87  3.08    ...      13.160000   9.04  7.46   9.59  19.680000
# 438   7.57  13.48  2.98    ...      10.450000   6.49  4.01   8.03  15.850000
# 445   6.15   9.82  2.37    ...       8.390000   4.85  3.60   3.00  14.270000
# 447   6.02   8.73  1.59    ...       6.770000   4.71  3.35   1.77  15.450000
#
#       cybe       fisi   agys      arcw       aciw
# 141  12.93  19.040001  20.00  4.959995  30.799999
# 215  12.06  17.660000  14.46  5.229995  22.360000
# 261  10.43  19.219999  14.90  5.299995  13.469999
# 264  10.34  17.299999  14.12  4.909995  12.480000
# 265  10.12  17.469999  14.79  4.899995  13.570001
# 266  10.08  18.510000  14.89  4.899995  13.400000
# 276  10.45  19.420000  11.91  4.749995  14.989999
# 438   8.90  20.000000  10.34  3.999996  16.510001
# 445   8.54  16.930000   6.95  3.899996  12.430000
# 447   7.96  14.440000   6.67  3.839996  11.120000
#
# [10 rows x 561 columns]

# %% [markdown]
# ## The Most Profitable Stock from 2007 to 2017

# %%
# using stocks_prices
def get_most_profitable(col):
    stock_dict = {}
    stock_dict['buy_date'] = '2001-01-03'
    stock_dict['buy_price'] = col[0]
    stock_dict['sell_date'] = time_periods[col.values.argmax]
    stock_dict['sell_price'] = max(col)
    
    return stock_dict

# %%
df_aapl = data['aapl']

# %%
stocks = data.keys()
most_profit_all_stocks = pd.DataFrame()
#most_profit_all_stocks.append(stocks_prices.apply(get_most_profitable, axis=0), ignore_index=True)  
#most_profit_all_stocks.head()
for stock in stocks:
    most_profit_all_stocks.append(get_most_profitable(stocks_prices[stock]), ignore_index=True)
    
most_profit_all_stocks.head()
# Out:
# /dataquest/system/env/python3/lib/python3.4/site-packages/pandas/core/common.py:477: FutureWarning: 'argmax' is deprecated. Use 'idxmax' instead. The behavior of 'argmax' will be corrected to return the positional maximum in the future. Use 'series.values.argmax' to get the position of the maximum now.
#   return maybe_callable(obj, **kwargs)
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## More to be done:

# %% [markdown]
# I've done some basic analysis of the data, but there's still quite a bit more depth to go into:
#
# - What stocks would have been best to short at the start of the period?
# - Which stocks have the most after-hours trading, and show the biggest changes between the closing price and the next day open?
# - Can technical indicators like Bollinger Bands help us forecast the market?
# - What time periods have resulted in steady increases in prices, and what periods have resulted in steady declines?
# - Based on price, what was the optimal day to buy each stock if we wanted to hold them until now?
# - On days with high trading volume, do stocks move in one direction (up or down) more than the other one?
